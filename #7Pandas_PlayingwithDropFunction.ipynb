# %%
import pandas as pd

# %%
df=pd.read_csv('F:\\dataset\\student_results.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0   10.0        2.0           9.0                     3.0
# 1      1002.0   10.0        6.0           8.0                     2.0
# 2      1003.0    NaN        3.0           8.0                     2.0
# 3      1004.0   11.0        0.0          10.0                     1.0
# 4      1005.0   11.0        4.0           7.0                     2.0
# 5         NaN    NaN        NaN           NaN                     NaN
# 6      1007.0   12.0        4.0           6.0                     0.0
# 7      1008.0   12.0       10.0           6.0                     2.0
# 8      1009.0   12.0        2.0           8.0                     2.0
# 9      1010.0   12.0        6.0           9.0                     1.0
#
#    Mobile Games hrs  Percantege
# 0               5.0        50.0
# 1               0.0        80.0
# 2               4.0        60.0
# 3               5.0        45.0
# ...

# %%
df.dropna()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   10.0          2             9                       3
# 1        1002   10.0          6             8                       2
# 3        1004   11.0          0            10                       1
# 4        1005   11.0          4             7                       2
# 5        1006   11.0         10             7                       0
# 6        1007   12.0          4             6                       0
# 7        1008   12.0         10             6                       2
# 8        1009   12.0          2             8                       2
# 9        1010   12.0          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 3                 5          45
# 4                 0          75
# 5                 0          96
# 6                 0          80
# 7                 0          90
# ...

# %%
df.dropna(axis=1)
# Out:
#    Student ID  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001          2             9                       3
# 1        1002          6             8                       2
# 2        1003          3             8                       2
# 3        1004          0            10                       1
# 4        1005          4             7                       2
# 5        1006         10             7                       0
# 6        1007          4             6                       0
# 7        1008         10             6                       2
# 8        1009          2             8                       2
# 9        1010          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# 4                 0          75
# 5                 0          96
# 6                 0          80
# ...

# %%
df.dropna(how = 'all')
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0   10.0        2.0           9.0                     3.0
# 1      1002.0   10.0        6.0           8.0                     2.0
# 2      1003.0    NaN        3.0           8.0                     2.0
# 3      1004.0   11.0        0.0          10.0                     1.0
# 4      1005.0   11.0        4.0           7.0                     2.0
# 6      1007.0   12.0        4.0           6.0                     0.0
# 7      1008.0   12.0       10.0           6.0                     2.0
# 8      1009.0   12.0        2.0           8.0                     2.0
# 9      1010.0   12.0        6.0           9.0                     1.0
#
#    Mobile Games hrs  Percantege
# 0               5.0        50.0
# 1               0.0        80.0
# 2               4.0        60.0
# 3               5.0        45.0
# 4               0.0        75.0
# 6               0.0        80.0
# 7               0.0        90.0
# ...

# %%
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   10.0          2             9                       3
# 1        1002   10.0          6             8                       2
# 2        1003    NaN          3             8                       2
# 3        1004   11.0          0            10                       1
# 4        1005   11.0          4             7                       2
# 5        1006   11.0         10             7                       0
# 6        1007   12.0          4             6                       0
# 7        1008   12.0         10             6                       2
# 8        1009   12.0          2             8                       2
# 9        1010   12.0          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0   10.0        2.0           9.0                     3.0
# 1      1002.0   10.0        6.0           8.0                     2.0
# 2      1003.0    NaN        3.0           8.0                     2.0
# 3      1004.0   11.0        0.0          10.0                     1.0
# 4      1005.0   11.0        4.0           7.0                     2.0
# 5         NaN    NaN        NaN           NaN                     NaN
# 6      1007.0   12.0        4.0           6.0                     0.0
# 7      1008.0   12.0       10.0           6.0                     2.0
# 8      1009.0   12.0        2.0           8.0                     2.0
# 9      1010.0   12.0        6.0           9.0                     1.0
#
#    Mobile Games hrs  Percantege
# 0               5.0        50.0
# 1               0.0        80.0
# 2               4.0        60.0
# 3               5.0        45.0
# ...

# %%
df.dropna(thresh=1) #atleast 1 notnull values containing rows
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0   10.0        2.0           9.0                     3.0
# 1      1002.0   10.0        6.0           8.0                     2.0
# 2      1003.0    NaN        3.0           8.0                     2.0
# 3      1004.0   11.0        0.0          10.0                     1.0
# 4      1005.0   11.0        4.0           7.0                     2.0
# 6      1007.0   12.0        4.0           6.0                     0.0
# 7      1008.0   12.0       10.0           6.0                     2.0
# 8      1009.0   12.0        2.0           8.0                     2.0
# 9      1010.0   12.0        6.0           9.0                     1.0
#
#    Mobile Games hrs  Percantege
# 0               5.0        50.0
# 1               0.0        80.0
# 2               4.0        60.0
# 3               5.0        45.0
# 4               0.0        75.0
# 6               0.0        80.0
# 7               0.0        90.0
# ...

# %%
df.dropna(thresh=7)   #atleast 7 notnull values containing rows
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0   10.0        2.0           9.0                     3.0
# 1      1002.0   10.0        6.0           8.0                     2.0
# 3      1004.0   11.0        0.0          10.0                     1.0
# 4      1005.0   11.0        4.0           7.0                     2.0
# 6      1007.0   12.0        4.0           6.0                     0.0
# 7      1008.0   12.0       10.0           6.0                     2.0
# 8      1009.0   12.0        2.0           8.0                     2.0
# 9      1010.0   12.0        6.0           9.0                     1.0
#
#    Mobile Games hrs  Percantege
# 0               5.0        50.0
# 1               0.0        80.0
# 3               5.0        45.0
# 4               0.0        75.0
# 6               0.0        80.0
# 7               0.0        90.0
# 8               4.0        60.0
# 9               0.0        85.0

# %%
df.dropna(subset=['Class'])
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0   10.0        2.0           9.0                     3.0
# 1      1002.0   10.0        6.0           8.0                     2.0
# 3      1004.0   11.0        0.0          10.0                     1.0
# 4      1005.0   11.0        4.0           7.0                     2.0
# 6      1007.0   12.0        4.0           6.0                     0.0
# 7      1008.0   12.0       10.0           6.0                     2.0
# 8      1009.0   12.0        2.0           8.0                     2.0
# 9      1010.0   12.0        6.0           9.0                     1.0
#
#    Mobile Games hrs  Percantege
# 0               5.0        50.0
# 1               0.0        80.0
# 3               5.0        45.0
# 4               0.0        75.0
# 6               0.0        80.0
# 7               0.0        90.0
# 8               4.0        60.0
# 9               0.0        85.0

# %%
df.dropna(inplace=True)
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0   10.0        2.0           9.0                     3.0
# 1      1002.0   10.0        6.0           8.0                     2.0
# 3      1004.0   11.0        0.0          10.0                     1.0
# 4      1005.0   11.0        4.0           7.0                     2.0
# 6      1007.0   12.0        4.0           6.0                     0.0
# 7      1008.0   12.0       10.0           6.0                     2.0
# 8      1009.0   12.0        2.0           8.0                     2.0
# 9      1010.0   12.0        6.0           9.0                     1.0
#
#    Mobile Games hrs  Percantege
# 0               5.0        50.0
# 1               0.0        80.0
# 3               5.0        45.0
# 4               0.0        75.0
# 6               0.0        80.0
# 7               0.0        90.0
# 8               4.0        60.0
# 9               0.0        85.0
