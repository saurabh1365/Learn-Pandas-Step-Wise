# %% [markdown]
# # how to write CSV file in Pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('F:\\dataset\\student_results.csv')
print(df)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Student ID', 'Class', 'Study hrs', 'Sleeping hrs',
#        'Social Media usage hrs', 'Mobile Games hrs', 'Percantege'],
#       dtype='object')

# %%
df=pd.read_csv('F:\\dataset\\student_results.csv',nrows=1)
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
#
#    Mobile Games hrs  Percantege
# 0                 5          50

# %%
df=pd.read_csv('F:\\dataset\\student_results.csv',usecols=[0])
df
# Out:
#    Student ID
# 0        1001
# 1        1002
# 2        1003
# 3        1004
# 4        1005
# 5        1006
# 6        1007
# 7        1008
# 8        1009
# 9        1010

# %%
df=pd.read_csv('F:\\dataset\\student_results.csv',usecols=[0,4])
df
# Out:
#    Student ID  Social Media usage hrs
# 0        1001                       3
# 1        1002                       2
# 2        1003                       2
# 3        1004                       1
# 4        1005                       2
# 5        1006                       0
# 6        1007                       0
# 7        1008                       2
# 8        1009                       2
# 9        1010                       1

# %%
df=pd.read_csv('F:\\dataset\\student_results.csv',usecols=[0,2,5])
df
# Out:
#    Student ID  Study hrs  Mobile Games hrs
# 0        1001          2                 5
# 1        1002          6                 0
# 2        1003          3                 4
# 3        1004          0                 5
# 4        1005          4                 0
# 5        1006         10                 0
# 6        1007          4                 0
# 7        1008         10                 0
# 8        1009          2                 4
# 9        1010          6                 0

# %%
 df=pd.read_csv('F:\\dataset\\student_results.csv',skiprows=2)
df
# Out:
#    1002  10   6   8  2  0  80
# 0  1003  10   3   8  2  4  60
# 1  1004  11   0  10  1  5  45
# 2  1005  11   4   7  2  0  75
# 3  1006  11  10   7  0  0  96
# 4  1007  12   4   6  0  0  80
# 5  1008  12  10   6  2  0  90
# 6  1009  12   2   8  2  4  60
# 7  1010  12   6   9  1  0  85

# %%
df=pd.read_csv('F:\\dataset\\student_results.csv',skiprows=[3])
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1004     11          0            10                       1
# 3        1005     11          4             7                       2
# 4        1006     11         10             7                       0
# 5        1007     12          4             6                       0
# 6        1008     12         10             6                       2
# 7        1009     12          2             8                       2
# 8        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 5          45
# 3                 0          75
# 4                 0          96
# 5                 0          80
# 6                 0          90
# ...

# %%
df=pd.read_csv('F:\\dataset\\student_results.csv',skiprows=[1,2,3])
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1004     11          0            10                       1
# 1        1005     11          4             7                       2
# 2        1006     11         10             7                       0
# 3        1007     12          4             6                       0
# 4        1008     12         10             6                       2
# 5        1009     12          2             8                       2
# 6        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          45
# 1                 0          75
# 2                 0          96
# 3                 0          80
# 4                 0          90
# 5                 4          60
# 6                 0          85

# %%
df=pd.read_csv('F:\\dataset\\student_results.csv',skiprows=[6,2,8])
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1003     10          3             8                       2
# 2        1004     11          0            10                       1
# 3        1005     11          4             7                       2
# 4        1007     12          4             6                       0
# 5        1009     12          2             8                       2
# 6        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 4          60
# 2                 5          45
# 3                 0          75
# 4                 0          80
# 5                 4          60
# 6                 0          85

# %%
df=pd.read_csv('F:\\dataset\\student_results.csv',index_col='Student ID')
df
# Out:
#             Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Student ID
# 1001           10          2             9                       3
# 1002           10          6             8                       2
# 1003           10          3             8                       2
# 1004           11          0            10                       1
# 1005           11          4             7                       2
# 1006           11         10             7                       0
# 1007           12          4             6                       0
# 1008           12         10             6                       2
# 1009           12          2             8                       2
# 1010           12          6             9                       1
#
#             Mobile Games hrs  Percantege
# Student ID
# 1001                       5          50
# 1002                       0          80
# 1003                       4          60
# ...
